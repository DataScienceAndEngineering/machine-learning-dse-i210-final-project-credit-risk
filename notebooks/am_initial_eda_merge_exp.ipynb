# %%
# %pip install polars

# %pip install pyarrow
# Out:
# Requirement already satisfied: polars in /opt/anaconda3/lib/python3.8/site-packages (0.20.14)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pyarrow in /opt/anaconda3/lib/python3.8/site-packages (15.0.2)
# Requirement already satisfied: numpy<2,>=1.16.6 in /opt/anaconda3/lib/python3.8/site-packages (from pyarrow) (1.24.4)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Files included in this EDA below and aggregation at the case_id level as part of this EDA:
#
# Properties: depth=0, internal data source
#     train_static_0_0.csv
#     train_static_0_1.csv
#
# Properties: depth=0, external data source
#     train_static_cb_0.csv
#
# Properties: depth=1, external data source, Tax registry provider A
#     test_tax_registry_a_1.csv
#
# Properties: depth=1, external data source, Tax registry provider B
#     test_tax_registry_b_1.csv
#
# Properties: depth=1, external data source, Tax registry provider C
#     train_tax_registry_c_1.csv

# %%
#Import necessary libraries
import polars as pl
from typing import List
from polars import DataFrame
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pyarrow as pow
from sklearn.preprocessing import OneHotEncoder

dataPath = "/Users/artjolameli/Desktop/Credit_Risk_Predictions/Kaggle_Credit_Risk_Predictions/dataset/home-credit-credit-risk-model-stability-2/parquet_files/train/"
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/scipy/__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
# Substitute this by the import 

def group_file_data(
    df: pl.DataFrame, 
    num_cols: List[str] = [], 
    date_cols: List[str] = [], 
    cat_cols: List[str] = []
) -> pl.DataFrame:
    '''
    Function to group numerical, date, and categorical columns

    Parameters:
    -----------
    df : Polars DataFrame
    num_cols : List of numerical column names (remember to drop num_group columns)
    date_cols : List of date column names
    cat_cols : List of categorical column names (becomes dummies)
    '''
    
    # Convert date columns
    df_date = df[['case_id'] + date_cols].with_columns([ pl.col(col).str.to_date() for col in date_cols ])

    # One-hot categories
    df_dummies = df[['case_id'] + cat_cols].to_dummies(cat_cols)

    # Num DataFrame
    df_num = df[['case_id'] + num_cols]

    # Date aggs
    date_aggs = [ pl.min(col).name.suffix('_min') for col in date_cols ] +\
                [ pl.max(col).name.suffix('_max') for col in date_cols ] +\
                [ pl.n_unique(col).name.suffix('_distinct') for col in date_cols]
    df_date_grouped = df_date.group_by('case_id').agg(date_aggs)

    # One-hot aggs
    dummy_cols = [ col for col in df_dummies.columns if col != 'case_id']
    dummies_aggs = [ pl.sum(col).name.suffix('_sum') for col in dummy_cols ]
    df_dummies_grouped = df_dummies.group_by('case_id').agg(dummies_aggs)

    # Numerical aggs
    num_aggs = [ pl.min(col).name.suffix('_min') for col in num_cols ] +\
            [ pl.max(col).name.suffix('_max') for col in num_cols ] +\
            [ pl.mean(col).name.suffix('_mean') for col in num_cols ] +\
            [ pl.median(col).name.suffix('_median') for col in num_cols ] +\
            [ pl.sum(col).name.suffix('_sum') for col in num_cols ]
    df_num_grouped = df_num.group_by('case_id').agg(num_aggs)

    # Join DataFrames
    df_joined = df_num_grouped.join(df_date_grouped, on='case_id')
    df_joined = df_joined.join(df_dummies_grouped, on='case_id')

    return df_joined

# %%
def set_table_dtypes(df: pl.DataFrame) -> pl.DataFrame:
    # implement here all desired dtypes for tables
    for col in df.columns:
        if col[-1] in ("P", "A"):
            df = df.with_columns(pl.col(col).cast(pl.Float64).alias(col))

    return df

def convert_strings(df: pd.DataFrame) -> pd.DataFrame:
    for col in df.columns:  
        if df[col].dtype.name in ['object', 'string']:
            df[col] = df[col].astype("string").astype('category')
            current_categories = df[col].cat.categories
            new_categories = current_categories.to_list() + ["Unknown"]
            new_dtype = pd.CategoricalDtype(categories=new_categories, ordered=True)
            df[col] = df[col].astype(new_dtype)
    return df

# %%
# Load each parquet file and print its schema
files = ["train_static_0_0.parquet", "train_static_0_1.parquet", "train_static_cb_0.parquet", 
         "train_tax_registry_a_1.parquet", "train_tax_registry_b_1.parquet", "train_tax_registry_c_1.parquet", "train_base.parquet"]
for file in files:
    df = pl.read_parquet(dataPath + file)
    print(f"Schema for {file}:")
    print(df.schema, "\n")
# Out:
# Schema for train_static_0_0.parquet:
# OrderedDict([('case_id', Int64), ('actualdpdtolerance_344P', Float64), ('amtinstpaidbefduel24m_4187115A', Float64), ('annuity_780A', Float64), ('annuitynextmonth_57A', Float64), ('applicationcnt_361L', Float64), ('applications30d_658L', Float64), ('applicationscnt_1086L', Float64), ('applicationscnt_464L', Float64), ('applicationscnt_629L', Float64), ('applicationscnt_867L', Float64), ('avgdbddpdlast24m_3658932P', Float64), ('avgdbddpdlast3m_4187120P', Float64), ('avgdbdtollast24m_4525197P', Float64), ('avgdpdtolclosure24_3658938P', Float64), ('avginstallast24m_3658937A', Float64), ('avglnamtstart24m_4525187A', Float64), ('avgmaxdpdlast9m_3716943P', Float64), ('avgoutstandbalancel6m_4187114A', Float64), ('avgpmtlast12m_4525200A', Float64), ('bankacctype_710L', String), ('cardtype_51L', String), ('clientscnt12m_3712952L', Float64), ('clientscnt3m_3712950L', Float64), ('clientscnt6m_3712949L', Float64), ('clientscnt_100L', Float64), ('clientscnt_1022L', Float64), ('clientscnt_1071L', Float64), ('clientscnt_1130L', Float64), ('clientscnt_136L', Float64), ('clientscnt_157L', Float64), ('clientscnt_257L', Float64), ('clientscnt_304L', Float64), ('clientscnt_360L', Float64), ('clientscnt_493L', Float64), ('clientscnt_533L', Float64), ('clientscnt_887L', Float64), ('clientscnt_946L', Float64), ('cntincpaycont9m_3716944L', Float64), ('cntpmts24_3658933L', Float64), ('commnoinclast6m_3546845L', Float64), ('credamount_770A', Float64), ('credtype_322L', String), ('currdebt_22A', Float64), ('currdebtcredtyperange_828A', Float64), ('datefirstoffer_1144D', String), ('datelastinstal40dpd_247D', String), ('datelastunpaid_3546854D', String), ('daysoverduetolerancedd_3976961L', Float64), ('deferredmnthsnum_166L', Float64), ('disbursedcredamount_1113A', Float64), ('disbursementtype_67L', String), ('downpmt_116A', Float64), ('dtlastpmtallstes_4499206D', String), ('eir_270L', Float64), ('equalitydataagreement_891L', Boolean), ('equalityempfrom_62L', Boolean), ('firstclxcampaign_1125D', String), ('firstdatedue_489D', String), ('homephncnt_628L', Float64), ('inittransactionamount_650A', Float64), ('inittransactioncode_186L', String), ('interestrate_311L', Float64), ('interestrategrace_34L', Float64), ('isbidproduct_1095L', Boolean), ('isbidproductrequest_292L', Boolean), ('isdebitcard_729L', Boolean), ('lastactivateddate_801D', String), ('lastapplicationdate_877D', String), ('lastapprcommoditycat_1041M', String), ('lastapprcommoditytypec_5251766M', String), ('lastapprcredamount_781A', Float64), ('lastapprdate_640D', String), ('lastcancelreason_561M', String), ('lastdelinqdate_224D', String), ('lastdependentsnum_448L', Float64), ('lastotherinc_902A', Float64), ('lastotherlnsexpense_631A', Float64), ('lastrejectcommoditycat_161M', String), ('lastrejectcommodtypec_5251769M', String), ('lastrejectcredamount_222A', Float64), ('lastrejectdate_50D', String), ('lastrejectreason_759M', String), ('lastrejectreasonclient_4145040M', String), ('lastrepayingdate_696D', String), ('lastst_736L', String), ('maininc_215A', Float64), ('mastercontrelectronic_519L', Float64), ('mastercontrexist_109L', Float64), ('maxannuity_159A', Float64), ('maxannuity_4075009A', Float64), ('maxdbddpdlast1m_3658939P', Float64), ('maxdbddpdtollast12m_3658940P', Float64), ('maxdbddpdtollast6m_4187119P', Float64), ('maxdebt4_972A', Float64), ('maxdpdfrom6mto36m_3546853P', Float64), ('maxdpdinstldate_3546855D', String), ('maxdpdinstlnum_3546846P', Float64), ('maxdpdlast12m_727P', Float64), ('maxdpdlast24m_143P', Float64), ('maxdpdlast3m_392P', Float64), ('maxdpdlast6m_474P', Float64), ('maxdpdlast9m_1059P', Float64), ('maxdpdtolerance_374P', Float64), ('maxinstallast24m_3658928A', Float64), ('maxlnamtstart6m_4525199A', Float64), ('maxoutstandbalancel12m_4187113A', Float64), ('maxpmtlast3m_4525190A', Float64), ('mindbddpdlast24m_3658935P', Float64), ('mindbdtollast24m_4525191P', Float64), ('mobilephncnt_593L', Float64), ('monthsannuity_845L', Float64), ('numactivecreds_622L', Float64), ('nu ...
#
# Schema for train_static_0_1.parquet:
# OrderedDict([('case_id', Int64), ('actualdpdtolerance_344P', Float64), ('amtinstpaidbefduel24m_4187115A', Float64), ('annuity_780A', Float64), ('annuitynextmonth_57A', Float64), ('applicationcnt_361L', Float64), ('applications30d_658L', Float64), ('applicationscnt_1086L', Float64), ('applicationscnt_464L', Float64), ('applicationscnt_629L', Float64), ('applicationscnt_867L', Float64), ('avgdbddpdlast24m_3658932P', Float64), ('avgdbddpdlast3m_4187120P', Float64), ('avgdbdtollast24m_4525197P', Float64), ('avgdpdtolclosure24_3658938P', Float64), ('avginstallast24m_3658937A', Float64), ('avglnamtstart24m_4525187A', Float64), ('avgmaxdpdlast9m_3716943P', Float64), ('avgoutstandbalancel6m_4187114A', Float64), ('avgpmtlast12m_4525200A', Float64), ('bankacctype_710L', String), ('cardtype_51L', String), ('clientscnt12m_3712952L', Float64), ('clientscnt3m_3712950L', Float64), ('clientscnt6m_3712949L', Float64), ('clientscnt_100L', Float64), ('clientscnt_1022L', Float64), ('clientscnt_1071L', Float64), ('clientscnt_1130L', Float64), ('clientscnt_136L', Float64), ('clientscnt_157L', Float64), ('clientscnt_257L', Float64), ('clientscnt_304L', Float64), ('clientscnt_360L', Float64), ('clientscnt_493L', Float64), ('clientscnt_533L', Float64), ('clientscnt_887L', Float64), ('clientscnt_946L', Float64), ('cntincpaycont9m_3716944L', Float64), ('cntpmts24_3658933L', Float64), ('commnoinclast6m_3546845L', Float64), ('credamount_770A', Float64), ('credtype_322L', String), ('currdebt_22A', Float64), ('currdebtcredtyperange_828A', Float64), ('datefirstoffer_1144D', String), ('datelastinstal40dpd_247D', String), ('datelastunpaid_3546854D', String), ('daysoverduetolerancedd_3976961L', Float64), ('deferredmnthsnum_166L', Float64), ('disbursedcredamount_1113A', Float64), ('disbursementtype_67L', String), ('downpmt_116A', Float64), ('dtlastpmtallstes_4499206D', String), ('eir_270L', Float64), ('equalitydataagreement_891L', Boolean), ('equalityempfrom_62L', Boolean), ('firstclxcampaign_1125D', String), ('firstdatedue_489D', String), ('homephncnt_628L', Float64), ('inittransactionamount_650A', Float64), ('inittransactioncode_186L', String), ('interestrate_311L', Float64), ('interestrategrace_34L', Float64), ('isbidproduct_1095L', Boolean), ('isbidproductrequest_292L', Boolean), ('isdebitcard_729L', Boolean), ('lastactivateddate_801D', String), ('lastapplicationdate_877D', String), ('lastapprcommoditycat_1041M', String), ('lastapprcommoditytypec_5251766M', String), ('lastapprcredamount_781A', Float64), ('lastapprdate_640D', String), ('lastcancelreason_561M', String), ('lastdelinqdate_224D', String), ('lastdependentsnum_448L', Float64), ('lastotherinc_902A', Float64), ('lastotherlnsexpense_631A', Float64), ('lastrejectcommoditycat_161M', String), ('lastrejectcommodtypec_5251769M', String), ('lastrejectcredamount_222A', Float64), ('lastrejectdate_50D', String), ('lastrejectreason_759M', String), ('lastrejectreasonclient_4145040M', String), ('lastrepayingdate_696D', String), ('lastst_736L', String), ('maininc_215A', Float64), ('mastercontrelectronic_519L', Float64), ('mastercontrexist_109L', Float64), ('maxannuity_159A', Float64), ('maxannuity_4075009A', Float64), ('maxdbddpdlast1m_3658939P', Float64), ('maxdbddpdtollast12m_3658940P', Float64), ('maxdbddpdtollast6m_4187119P', Float64), ('maxdebt4_972A', Float64), ('maxdpdfrom6mto36m_3546853P', Float64), ('maxdpdinstldate_3546855D', String), ('maxdpdinstlnum_3546846P', Float64), ('maxdpdlast12m_727P', Float64), ('maxdpdlast24m_143P', Float64), ('maxdpdlast3m_392P', Float64), ('maxdpdlast6m_474P', Float64), ('maxdpdlast9m_1059P', Float64), ('maxdpdtolerance_374P', Float64), ('maxinstallast24m_3658928A', Float64), ('maxlnamtstart6m_4525199A', Float64), ('maxoutstandbalancel12m_4187113A', Float64), ('maxpmtlast3m_4525190A', Float64), ('mindbddpdlast24m_3658935P', Float64), ('mindbdtollast24m_4525191P', Float64), ('mobilephncnt_593L', Float64), ('monthsannuity_845L', Float64), ('numactivecreds_622L', Float64), ('nu ...
#
# Schema for train_static_cb_0.parquet:
# OrderedDict([('case_id', Int64), ('assignmentdate_238D', String), ('assignmentdate_4527235D', String), ('assignmentdate_4955616D', String), ('birthdate_574D', String), ('contractssum_5085716L', Float64), ('dateofbirth_337D', String), ('dateofbirth_342D', String), ('days120_123L', Float64), ('days180_256L', Float64), ('days30_165L', Float64), ('days360_512L', Float64), ('days90_310L', Float64), ('description_5085714M', String), ('education_1103M', String), ('education_88M', String), ('firstquarter_103L', Float64), ('for3years_128L', Float64), ('for3years_504L', Float64), ('for3years_584L', Float64), ('formonth_118L', Float64), ('formonth_206L', Float64), ('formonth_535L', Float64), ('forquarter_1017L', Float64), ('forquarter_462L', Float64), ('forquarter_634L', Float64), ('fortoday_1092L', Float64), ('forweek_1077L', Float64), ('forweek_528L', Float64), ('forweek_601L', Float64), ('foryear_618L', Float64), ('foryear_818L', Float64), ('foryear_850L', Float64), ('fourthquarter_440L', Float64), ('maritalst_385M', String), ('maritalst_893M', String), ('numberofqueries_373L', Float64), ('pmtaverage_3A', Float64), ('pmtaverage_4527227A', Float64), ('pmtaverage_4955615A', Float64), ('pmtcount_4527229L', Float64), ('pmtcount_4955617L', Float64), ('pmtcount_693L', Float64), ('pmtscount_423L', Float64), ('pmtssum_45A', Float64), ('requesttype_4525192L', String), ('responsedate_1012D', String), ('responsedate_4527233D', String), ('responsedate_4917613D', String), ('riskassesment_302T', String), ('riskassesment_940T', Float64), ('secondquarter_766L', Float64), ('thirdquarter_1082L', Float64)])
#
# Schema for train_tax_registry_a_1.parquet:
# OrderedDict([('case_id', Int64), ('amount_4527230A', Float64), ('name_4527232M', String), ('num_group1', Int64), ('recorddate_4527225D', String)])
#
# Schema for train_tax_registry_b_1.parquet:
# OrderedDict([('case_id', Int64), ('amount_4917619A', Float64), ('deductiondate_4917603D', String), ('name_4917606M', String), ('num_group1', Int64)])
#
# Schema for train_tax_registry_c_1.parquet:
# OrderedDict([('case_id', Int64), ('employername_160M', String), ('num_group1', Int64), ('pmtamount_36A', Float64), ('processingdate_168D', String)])
#
# Schema for train_base.parquet:
# OrderedDict([('case_id', Int64), ('date_decision', String), ('MONTH', Int64), ('WEEK_NUM', Int64), ('target', Int64)])

# %% [markdown]
# "recorddate_4527225D" column in train_tax_registry_a file is the same as "deductiondate_4917603D" and "processingdate_168D" in "train_tax_registry_c"
#
# "name_4527232M" in train_tax_registry_a file, "name_4917606M" in train_tax_registry_b file and "employername_160M" in "train_tax_registry_c" are same.
#
# "amount_4527230A" in train_tax_registry_a file, "amount_4917619A" in train_tax_registry_b file and "pmtamount_36A" in train_tax_registry_c are the same.

# %%
# Load and merge the static and tax_registry files + base file as well as we will use it later for the aggregation

train_basetable = pl.read_parquet(dataPath + "train_base.parquet")


# Load the rest of the parquet files separately
train_static_0_0 = pl.read_parquet(dataPath + "train_static_0_0.parquet").pipe(set_table_dtypes)
train_static_0_1 = pl.read_parquet(dataPath + "train_static_0_1.parquet").pipe(set_table_dtypes)
train_static_cb = pl.read_parquet(dataPath + "train_static_cb_0.parquet").pipe(set_table_dtypes)
train_tax_registry_a = pl.read_parquet(dataPath + "train_tax_registry_a_1.parquet").pipe(set_table_dtypes)
train_tax_registry_b = pl.read_parquet(dataPath + "train_tax_registry_b_1.parquet").pipe(set_table_dtypes)
train_tax_registry_c = pl.read_parquet(dataPath + "train_tax_registry_c_1.parquet").pipe(set_table_dtypes)

# %%
# Overview and statistics for each DataFrame
dataframes = {
    'train_static_0_0': train_static_0_0,
    'train_static_0_1': train_static_0_1,
    'train_static_cb': train_static_cb,
    'train_tax_registry_a': train_tax_registry_a,
    'train_tax_registry_b': train_tax_registry_b,
    'train_tax_registry_c': train_tax_registry_c
}

for name, df in dataframes.items():
    print(f"Overview of {name}:")
    # Print the schema for an overview of the DataFrame structure
    print(df.schema)
    
    # Get a summary of the data
    print(df.describe())

    print("\nMissing values count in each column:")
    # Count missing values in each column
    missing_values = df.select([pl.col(column).is_null().sum().alias(column) for column in df.columns])
    print(missing_values)

    print("\n-----\n")
# Out:
# Overview of train_static_0_0:
# OrderedDict([('case_id', Int64), ('actualdpdtolerance_344P', Float64), ('amtinstpaidbefduel24m_4187115A', Float64), ('annuity_780A', Float64), ('annuitynextmonth_57A', Float64), ('applicationcnt_361L', Float64), ('applications30d_658L', Float64), ('applicationscnt_1086L', Float64), ('applicationscnt_464L', Float64), ('applicationscnt_629L', Float64), ('applicationscnt_867L', Float64), ('avgdbddpdlast24m_3658932P', Float64), ('avgdbddpdlast3m_4187120P', Float64), ('avgdbdtollast24m_4525197P', Float64), ('avgdpdtolclosure24_3658938P', Float64), ('avginstallast24m_3658937A', Float64), ('avglnamtstart24m_4525187A', Float64), ('avgmaxdpdlast9m_3716943P', Float64), ('avgoutstandbalancel6m_4187114A', Float64), ('avgpmtlast12m_4525200A', Float64), ('bankacctype_710L', String), ('cardtype_51L', String), ('clientscnt12m_3712952L', Float64), ('clientscnt3m_3712950L', Float64), ('clientscnt6m_3712949L', Float64), ('clientscnt_100L', Float64), ('clientscnt_1022L', Float64), ('clientscnt_1071L', Float64), ('clientscnt_1130L', Float64), ('clientscnt_136L', Float64), ('clientscnt_157L', Float64), ('clientscnt_257L', Float64), ('clientscnt_304L', Float64), ('clientscnt_360L', Float64), ('clientscnt_493L', Float64), ('clientscnt_533L', Float64), ('clientscnt_887L', Float64), ('clientscnt_946L', Float64), ('cntincpaycont9m_3716944L', Float64), ('cntpmts24_3658933L', Float64), ('commnoinclast6m_3546845L', Float64), ('credamount_770A', Float64), ('credtype_322L', String), ('currdebt_22A', Float64), ('currdebtcredtyperange_828A', Float64), ('datefirstoffer_1144D', String), ('datelastinstal40dpd_247D', String), ('datelastunpaid_3546854D', String), ('daysoverduetolerancedd_3976961L', Float64), ('deferredmnthsnum_166L', Float64), ('disbursedcredamount_1113A', Float64), ('disbursementtype_67L', String), ('downpmt_116A', Float64), ('dtlastpmtallstes_4499206D', String), ('eir_270L', Float64), ('equalitydataagreement_891L', Boolean), ('equalityempfrom_62L', Boolean), ('firstclxcampaign_1125D', String), ('firstdatedue_489D', String), ('homephncnt_628L', Float64), ('inittransactionamount_650A', Float64), ('inittransactioncode_186L', String), ('interestrate_311L', Float64), ('interestrategrace_34L', Float64), ('isbidproduct_1095L', Boolean), ('isbidproductrequest_292L', Boolean), ('isdebitcard_729L', Boolean), ('lastactivateddate_801D', String), ('lastapplicationdate_877D', String), ('lastapprcommoditycat_1041M', String), ('lastapprcommoditytypec_5251766M', String), ('lastapprcredamount_781A', Float64), ('lastapprdate_640D', String), ('lastcancelreason_561M', String), ('lastdelinqdate_224D', String), ('lastdependentsnum_448L', Float64), ('lastotherinc_902A', Float64), ('lastotherlnsexpense_631A', Float64), ('lastrejectcommoditycat_161M', String), ('lastrejectcommodtypec_5251769M', String), ('lastrejectcredamount_222A', Float64), ('lastrejectdate_50D', String), ('lastrejectreason_759M', String), ('lastrejectreasonclient_4145040M', String), ('lastrepayingdate_696D', String), ('lastst_736L', String), ('maininc_215A', Float64), ('mastercontrelectronic_519L', Float64), ('mastercontrexist_109L', Float64), ('maxannuity_159A', Float64), ('maxannuity_4075009A', Float64), ('maxdbddpdlast1m_3658939P', Float64), ('maxdbddpdtollast12m_3658940P', Float64), ('maxdbddpdtollast6m_4187119P', Float64), ('maxdebt4_972A', Float64), ('maxdpdfrom6mto36m_3546853P', Float64), ('maxdpdinstldate_3546855D', String), ('maxdpdinstlnum_3546846P', Float64), ('maxdpdlast12m_727P', Float64), ('maxdpdlast24m_143P', Float64), ('maxdpdlast3m_392P', Float64), ('maxdpdlast6m_474P', Float64), ('maxdpdlast9m_1059P', Float64), ('maxdpdtolerance_374P', Float64), ('maxinstallast24m_3658928A', Float64), ('maxlnamtstart6m_4525199A', Float64), ('maxoutstandbalancel12m_4187113A', Float64), ('maxpmtlast3m_4525190A', Float64), ('mindbddpdlast24m_3658935P', Float64), ('mindbdtollast24m_4525191P', Float64), ('mobilephncnt_593L', Float64), ('monthsannuity_845L', Float64), ('numactivecreds_622L', Float64), ('nu ...
# shape: (9, 169)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ statistic ┆ case_id   ┆ actualdpd ┆ amtinstpa ┆ … ┆ totinstal ┆ twobodfil ┆ typesuite ┆ validfro │
# │ ---       ┆ ---       ┆ tolerance ┆ idbefduel ┆   ┆ last1m_45 ┆ ling_608L ┆ _864L     ┆ m_1069D  │
# │ str       ┆ f64       ┆ _344P     ┆ 24m_41871 ┆   ┆ 25188A    ┆ ---       ┆ ---       ┆ ---      │
# │           ┆           ┆ ---       ┆ 15A       ┆   ┆ ---       ┆ str       ┆ str       ┆ str      │
# │           ┆           ┆ f64       ┆ ---       ┆   ┆ f64       ┆           ┆           ┆          │
# │           ┆           ┆           ┆ f64       ┆   ┆           ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ count     ┆ 1.003757e ┆ 707071.0  ┆ 574903.0  ┆ … ┆ 138692.0  ┆ 1003712   ┆ 288520    ┆ 119405   │
# │           ┆ 6         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ null_coun ┆ 0.0       ┆ 296686.0  ┆ 428854.0  ┆ … ┆ 865065.0  ┆ 45        ┆ 715237    ┆ 884352   │
# │ t         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ mean      ┆ 1.2169e6  ┆ 0.054391  ┆ 50692.545 ┆ … ┆ 10576.192 ┆ null      ┆ null      ┆ null     │
# │           ┆           ┆           ┆ 111       ┆   ┆ 565       ┆           ┆           ┆          │
# │ std       ┆ 696462.44 ┆ 8.743984  ┆ 65457.938 ┆ … ┆ 16354.417 ┆ null      ┆ null      ┆ null     │
# │           ┆ 1593      ┆           ┆ 573       ┆   ┆ 83        ┆           ┆           ┆          │
# │ min       ┆ 0.0       ┆ 0.0       ┆ 0.0       ┆ … ┆ 0.222     ┆ BO        ┆ AL        ┆ 2018-09- │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 22       │
# │ 25%       ┆ 725987.0  ┆ 0.0       ┆ 6453.0    ┆ … ┆ 3142.4001 ┆ null      ┆ null      ┆ null     │
# │ 50%       ┆ 1.3117e6  ┆ 0.0       ┆ 26937.0   ┆ … ┆ 6008.6    ┆ null      ┆ null      ┆ null     │
# │ 75%       ┆ 1.562639e ┆ 0.0       ┆ 68961.2   ┆ … ┆ 11627.2   ┆ null      ┆ null      ┆ null     │
# │           ┆ 6         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ max       ┆ 2.651092e ┆ 3676.0    ┆ 992476.5  ┆ … ┆ 794899.2  ┆ FO        ┆ AL        ┆ 2019-12- │
# │           ┆ 6         ┆           ┆           ┆   ┆           ┆           ┆           ┆ 30       │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘
#
# Missing values count in each column:
# shape: (1, 168)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ case_id ┆ actualdpdt ┆ amtinstpa ┆ annuity_7 ┆ … ┆ totinstal ┆ twobodfil ┆ typesuite ┆ validfrom │
# │ ---     ┆ olerance_3 ┆ idbefduel ┆ 80A       ┆   ┆ last1m_45 ┆ ling_608L ┆ _864L     ┆ _1069D    │
# │ u32     ┆ 44P        ┆ 24m_41871 ┆ ---       ┆   ┆ 25188A    ┆ ---       ┆ ---       ┆ ---       │
# │         ┆ ---        ┆ 15A       ┆ u32       ┆   ┆ ---       ┆ u32       ┆ u32       ┆ u32       │
# │         ┆ u32        ┆ ---       ┆           ┆   ┆ u32       ┆           ┆           ┆           │
# │         ┆            ┆ u32       ┆           ┆   ┆           ┆           ┆           ┆           │
# ╞═════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 0       ┆ 296686     ┆ 428854    ┆ 0         ┆ … ┆ 865065    ┆ 45        ┆ 715237    ┆ 884352    │
# └─────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
#
# -----
#
# Overview of train_static_0_1:
# OrderedDict([('case_id', Int64), ('actualdpdtolerance_344P', Float64), ('amtinstpaidbefduel24m_4187115A', Float64), ('annuity_780A', Float64), ('annuitynextmonth_57A', Float64), ('applicationcnt_361L', Float64), ('applications30d_658L', Float64), ('applicationscnt_1086L', Float64), ('applicationscnt_464L', Float64), ('applicationscnt_629L', Float64), ('applicationscnt_867L', Float64), ('avgdbddpdlast24m_3658932P', Float64), ('avgdbddpdlast3m_4187120P', Float64), ('avgdbdtollast24m_4525197P', Float64), ('avgdpdtolclosure24_3658938P', Float64), ('avginstallast24m_3658937A', Float64), ('avglnamtstart24m_4525187A', Float64), ('avgmaxdpdlast9m_3716943P', Float64), ('avgoutstandbalancel6m_4187114A', Float64), ('avgpmtlast12m_4525200A', Float64), ('bankacctype_710L', String), ('cardtype_51L', String), ('clientscnt12m_3712952L', Float64), ('clientscnt3m_3712950L', Float64), ('clientscnt6m_3712949L', Float64), ('clientscnt_100L', Float64), ('clientscnt_1022L', Float64), ('clientscnt_1071L', Float64), ('clientscnt_1130L', Float64), ('clientscnt_136L', Float64), ('clientscnt_157L', Float64), ('clientscnt_257L', Float64), ('clientscnt_304L', Float64), ('clientscnt_360L', Float64), ('clientscnt_493L', Float64), ('clientscnt_533L', Float64), ('clientscnt_887L', Float64), ('clientscnt_946L', Float64), ('cntincpaycont9m_3716944L', Float64), ('cntpmts24_3658933L', Float64), ('commnoinclast6m_3546845L', Float64), ('credamount_770A', Float64), ('credtype_322L', String), ('currdebt_22A', Float64), ('currdebtcredtyperange_828A', Float64), ('datefirstoffer_1144D', String), ('datelastinstal40dpd_247D', String), ('datelastunpaid_3546854D', String), ('daysoverduetolerancedd_3976961L', Float64), ('deferredmnthsnum_166L', Float64), ('disbursedcredamount_1113A', Float64), ('disbursementtype_67L', String), ('downpmt_116A', Float64), ('dtlastpmtallstes_4499206D', String), ('eir_270L', Float64), ('equalitydataagreement_891L', Boolean), ('equalityempfrom_62L', Boolean), ('firstclxcampaign_1125D', String), ('firstdatedue_489D', String), ('homephncnt_628L', Float64), ('inittransactionamount_650A', Float64), ('inittransactioncode_186L', String), ('interestrate_311L', Float64), ('interestrategrace_34L', Float64), ('isbidproduct_1095L', Boolean), ('isbidproductrequest_292L', Boolean), ('isdebitcard_729L', Boolean), ('lastactivateddate_801D', String), ('lastapplicationdate_877D', String), ('lastapprcommoditycat_1041M', String), ('lastapprcommoditytypec_5251766M', String), ('lastapprcredamount_781A', Float64), ('lastapprdate_640D', String), ('lastcancelreason_561M', String), ('lastdelinqdate_224D', String), ('lastdependentsnum_448L', Float64), ('lastotherinc_902A', Float64), ('lastotherlnsexpense_631A', Float64), ('lastrejectcommoditycat_161M', String), ('lastrejectcommodtypec_5251769M', String), ('lastrejectcredamount_222A', Float64), ('lastrejectdate_50D', String), ('lastrejectreason_759M', String), ('lastrejectreasonclient_4145040M', String), ('lastrepayingdate_696D', String), ('lastst_736L', String), ('maininc_215A', Float64), ('mastercontrelectronic_519L', Float64), ('mastercontrexist_109L', Float64), ('maxannuity_159A', Float64), ('maxannuity_4075009A', Float64), ('maxdbddpdlast1m_3658939P', Float64), ('maxdbddpdtollast12m_3658940P', Float64), ('maxdbddpdtollast6m_4187119P', Float64), ('maxdebt4_972A', Float64), ('maxdpdfrom6mto36m_3546853P', Float64), ('maxdpdinstldate_3546855D', String), ('maxdpdinstlnum_3546846P', Float64), ('maxdpdlast12m_727P', Float64), ('maxdpdlast24m_143P', Float64), ('maxdpdlast3m_392P', Float64), ('maxdpdlast6m_474P', Float64), ('maxdpdlast9m_1059P', Float64), ('maxdpdtolerance_374P', Float64), ('maxinstallast24m_3658928A', Float64), ('maxlnamtstart6m_4525199A', Float64), ('maxoutstandbalancel12m_4187113A', Float64), ('maxpmtlast3m_4525190A', Float64), ('mindbddpdlast24m_3658935P', Float64), ('mindbdtollast24m_4525191P', Float64), ('mobilephncnt_593L', Float64), ('monthsannuity_845L', Float64), ('numactivecreds_622L', Float64), ('nu ...
# shape: (9, 169)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ statistic ┆ case_id   ┆ actualdpd ┆ amtinstpa ┆ … ┆ totinstal ┆ twobodfil ┆ typesuite ┆ validfro │
# │ ---       ┆ ---       ┆ tolerance ┆ idbefduel ┆   ┆ last1m_45 ┆ ling_608L ┆ _864L     ┆ m_1069D  │
# │ str       ┆ f64       ┆ _344P     ┆ 24m_41871 ┆   ┆ 25188A    ┆ ---       ┆ ---       ┆ ---      │
# │           ┆           ┆ ---       ┆ 15A       ┆   ┆ ---       ┆ str       ┆ str       ┆ str      │
# │           ┆           ┆ f64       ┆ ---       ┆   ┆ f64       ┆           ┆           ┆          │
# │           ┆           ┆           ┆ f64       ┆   ┆           ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ count     ┆ 522902.0  ┆ 401410.0  ┆ 390632.0  ┆ … ┆ 213756.0  ┆ 522856    ┆ 116634    ┆ 32368    │
# │ null_coun ┆ 0.0       ┆ 121492.0  ┆ 132270.0  ┆ … ┆ 309146.0  ┆ 46        ┆ 406268    ┆ 490534   │
# │ t         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ mean      ┆ 1.4188e6  ┆ 0.122994  ┆ 63708.119 ┆ … ┆ 10304.440 ┆ null      ┆ null      ┆ null     │
# │           ┆           ┆           ┆ 594       ┆   ┆ 113       ┆           ┆           ┆          │
# │ std       ┆ 742410.95 ┆ 14.564417 ┆ 79181.095 ┆ … ┆ 16136.151 ┆ null      ┆ null      ┆ null     │
# │           ┆ 6327      ┆           ┆ 503       ┆   ┆ 448       ┆           ┆           ┆          │
# │ min       ┆ 40626.0   ┆ 0.0       ┆ 0.0       ┆ … ┆ 0.214     ┆ BO        ┆ AL        ┆ 2019-09- │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 21       │
# │ 25%       ┆ 942363.0  ┆ 0.0       ┆ 9042.601  ┆ … ┆ 3409.0    ┆ null      ┆ null      ┆ null     │
# │ 50%       ┆ 1.73803e6 ┆ 0.0       ┆ 34623.13  ┆ … ┆ 6343.0    ┆ null      ┆ null      ┆ null     │
# │ 75%       ┆ 1.868755e ┆ 0.0       ┆ 88321.805 ┆ … ┆ 11726.0   ┆ null      ┆ null      ┆ null     │
# │           ┆ 6         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ max       ┆ 2.703454e ┆ 4206.0    ┆ 1408010.2 ┆ … ┆ 543734.2  ┆ FO        ┆ AL        ┆ 2020-06- │
# │           ┆ 6         ┆           ┆           ┆   ┆           ┆           ┆           ┆ 22       │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘
#
# Missing values count in each column:
# shape: (1, 168)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ case_id ┆ actualdpdt ┆ amtinstpa ┆ annuity_7 ┆ … ┆ totinstal ┆ twobodfil ┆ typesuite ┆ validfrom │
# │ ---     ┆ olerance_3 ┆ idbefduel ┆ 80A       ┆   ┆ last1m_45 ┆ ling_608L ┆ _864L     ┆ _1069D    │
# │ u32     ┆ 44P        ┆ 24m_41871 ┆ ---       ┆   ┆ 25188A    ┆ ---       ┆ ---       ┆ ---       │
# │         ┆ ---        ┆ 15A       ┆ u32       ┆   ┆ ---       ┆ u32       ┆ u32       ┆ u32       │
# │         ┆ u32        ┆ ---       ┆           ┆   ┆ u32       ┆           ┆           ┆           │
# │         ┆            ┆ u32       ┆           ┆   ┆           ┆           ┆           ┆           │
# ╞═════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 0       ┆ 121492     ┆ 132270    ┆ 0         ┆ … ┆ 309146    ┆ 46        ┆ 406268    ┆ 490534    │
# └─────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
#
# -----
#
# Overview of train_static_cb:
# OrderedDict([('case_id', Int64), ('assignmentdate_238D', String), ('assignmentdate_4527235D', String), ('assignmentdate_4955616D', String), ('birthdate_574D', String), ('contractssum_5085716L', Float64), ('dateofbirth_337D', String), ('dateofbirth_342D', String), ('days120_123L', Float64), ('days180_256L', Float64), ('days30_165L', Float64), ('days360_512L', Float64), ('days90_310L', Float64), ('description_5085714M', String), ('education_1103M', String), ('education_88M', String), ('firstquarter_103L', Float64), ('for3years_128L', Float64), ('for3years_504L', Float64), ('for3years_584L', Float64), ('formonth_118L', Float64), ('formonth_206L', Float64), ('formonth_535L', Float64), ('forquarter_1017L', Float64), ('forquarter_462L', Float64), ('forquarter_634L', Float64), ('fortoday_1092L', Float64), ('forweek_1077L', Float64), ('forweek_528L', Float64), ('forweek_601L', Float64), ('foryear_618L', Float64), ('foryear_818L', Float64), ('foryear_850L', Float64), ('fourthquarter_440L', Float64), ('maritalst_385M', String), ('maritalst_893M', String), ('numberofqueries_373L', Float64), ('pmtaverage_3A', Float64), ('pmtaverage_4527227A', Float64), ('pmtaverage_4955615A', Float64), ('pmtcount_4527229L', Float64), ('pmtcount_4955617L', Float64), ('pmtcount_693L', Float64), ('pmtscount_423L', Float64), ('pmtssum_45A', Float64), ('requesttype_4525192L', String), ('responsedate_1012D', String), ('responsedate_4527233D', String), ('responsedate_4917613D', String), ('riskassesment_302T', String), ('riskassesment_940T', Float64), ('secondquarter_766L', Float64), ('thirdquarter_1082L', Float64)])
# shape: (9, 54)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ statistic ┆ case_id   ┆ assignmen ┆ assignmen ┆ … ┆ riskasses ┆ riskasses ┆ secondqua ┆ thirdqua │
# │ ---       ┆ ---       ┆ tdate_238 ┆ tdate_452 ┆   ┆ ment_302T ┆ ment_940T ┆ rter_766L ┆ rter_108 │
# │ str       ┆ f64       ┆ D         ┆ 7235D     ┆   ┆ ---       ┆ ---       ┆ ---       ┆ 2L       │
# │           ┆           ┆ ---       ┆ ---       ┆   ┆ str       ┆ f64       ┆ f64       ┆ ---      │
# │           ┆           ┆ str       ┆ str       ┆   ┆           ┆           ┆           ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ count     ┆ 1.500476e ┆ 136996    ┆ 114978    ┆ … ┆ 53559     ┆ 53560.0   ┆ 1.385691e ┆ 1.385691 │
# │           ┆ 6         ┆           ┆           ┆   ┆           ┆           ┆ 6         ┆ e6       │
# │ null_coun ┆ 0.0       ┆ 1363480   ┆ 1385498   ┆ … ┆ 1446917   ┆ 1.446916e ┆ 114785.0  ┆ 114785.0 │
# │ t         ┆           ┆           ┆           ┆   ┆           ┆ 6         ┆           ┆          │
# │ mean      ┆ 1.2840e6  ┆ null      ┆ null      ┆ … ┆ null      ┆ 0.225968  ┆ 2.688482  ┆ 2.918342 │
# │ std       ┆ 716088.12 ┆ null      ┆ null      ┆ … ┆ null      ┆ 0.97617   ┆ 3.324546  ┆ 3.423862 │
# │           ┆ 3478      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ min       ┆ 357.0     ┆ 1974-05-3 ┆ 2019-09-1 ┆ … ┆ 1% - 1%   ┆ -3.670423 ┆ 0.0       ┆ 0.0      │
# │           ┆           ┆ 0         ┆ 3         ┆   ┆           ┆           ┆           ┆          │
# │ 25%       ┆ 768509.0  ┆ null      ┆ null      ┆ … ┆ null      ┆ -0.227985 ┆ 0.0       ┆ 0.0      │
# │ 50%       ┆ 1.361879e ┆ null      ┆ null      ┆ … ┆ null      ┆ 0.371834  ┆ 2.0       ┆ 2.0      │
# │           ┆ 6         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 75%       ┆ 1.73701e6 ┆ null      ┆ null      ┆ … ┆ null      ┆ 0.9716525 ┆ 4.0       ┆ 4.0      │
# │ max       ┆ 2.703454e ┆ 2019-10-2 ┆ 2020-10-1 ┆ … ┆ 8% - 11%  ┆ 2.1191318 ┆ 109.0     ┆ 62.0     │
# │           ┆ 6         ┆ 2         ┆ 9         ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘
#
# Missing values count in each column:
# shape: (1, 53)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ case_id ┆ assignment ┆ assignmen ┆ assignmen ┆ … ┆ riskasses ┆ riskasses ┆ secondqua ┆ thirdquar │
# │ ---     ┆ date_238D  ┆ tdate_452 ┆ tdate_495 ┆   ┆ ment_302T ┆ ment_940T ┆ rter_766L ┆ ter_1082L │
# │ u32     ┆ ---        ┆ 7235D     ┆ 5616D     ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │         ┆ u32        ┆ ---       ┆ ---       ┆   ┆ u32       ┆ u32       ┆ u32       ┆ u32       │
# │         ┆            ┆ u32       ┆ u32       ┆   ┆           ┆           ┆           ┆           │
# ╞═════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 0       ┆ 1363480    ┆ 1385498   ┆ 1428843   ┆ … ┆ 1446917   ┆ 1446916   ┆ 114785    ┆ 114785    │
# └─────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
#
# -----
#
# Overview of train_tax_registry_a:
# OrderedDict([('case_id', Int64), ('amount_4527230A', Float64), ('name_4527232M', String), ('num_group1', Int64), ('recorddate_4527225D', String)])
# shape: (9, 6)
# ┌────────────┬───────────────┬─────────────────┬───────────────┬────────────┬─────────────────────┐
# │ statistic  ┆ case_id       ┆ amount_4527230A ┆ name_4527232M ┆ num_group1 ┆ recorddate_4527225D │
# │ ---        ┆ ---           ┆ ---             ┆ ---           ┆ ---        ┆ ---                 │
# │ str        ┆ f64           ┆ f64             ┆ str           ┆ f64        ┆ str                 │
# ╞════════════╪═══════════════╪═════════════════╪═══════════════╪════════════╪═════════════════════╡
# │ count      ┆ 3.27577e6     ┆ 3.27577e6       ┆ 3275770       ┆ 3.27577e6  ┆ 3275770             │
# │ null_count ┆ 0.0           ┆ 0.0             ┆ 0             ┆ 0.0        ┆ 0                   │
# │ mean       ┆ 1.3414e6      ┆ 2360.421376     ┆ null          ┆ 4.095616   ┆ null                │
# │ std        ┆ 649263.451335 ┆ 3254.871236     ┆ null          ┆ 3.933319   ┆ null                │
# │ min        ┆ 28631.0       ┆ 0.0             ┆ 000025c1      ┆ 0.0        ┆ 2019-09-13          │
# │ 25%        ┆ 877291.0      ┆ 850.0           ┆ null          ┆ 1.0        ┆ null                │
# │ 50%        ┆ 1.571545e6    ┆ 1400.0          ┆ null          ┆ 3.0        ┆ null                │
# │ 75%        ┆ 1.728466e6    ┆ 2778.0          ┆ null          ┆ 5.0        ┆ null                │
# │ max        ┆ 2.70229e6     ┆ 87115.6         ┆ ffffa404      ┆ 98.0       ┆ 2020-10-19          │
# └────────────┴───────────────┴─────────────────┴───────────────┴────────────┴─────────────────────┘
#
# Missing values count in each column:
# shape: (1, 5)
# ┌─────────┬─────────────────┬───────────────┬────────────┬─────────────────────┐
# │ case_id ┆ amount_4527230A ┆ name_4527232M ┆ num_group1 ┆ recorddate_4527225D │
# │ ---     ┆ ---             ┆ ---           ┆ ---        ┆ ---                 │
# │ u32     ┆ u32             ┆ u32           ┆ u32        ┆ u32                 │
# ╞═════════╪═════════════════╪═══════════════╪════════════╪═════════════════════╡
# │ 0       ┆ 0               ┆ 0             ┆ 0          ┆ 0                   │
# └─────────┴─────────────────┴───────────────┴────────────┴─────────────────────┘
#
# -----
#
# Overview of train_tax_registry_b:
# OrderedDict([('case_id', Int64), ('amount_4917619A', Float64), ('deductiondate_4917603D', String), ('name_4917606M', String), ('num_group1', Int64)])
# shape: (9, 6)
# ┌────────────┬───────────────┬─────────────────┬──────────────────────┬───────────────┬────────────┐
# │ statistic  ┆ case_id       ┆ amount_4917619A ┆ deductiondate_491760 ┆ name_4917606M ┆ num_group1 │
# │ ---        ┆ ---           ┆ ---             ┆ 3D                   ┆ ---           ┆ ---        │
# │ str        ┆ f64           ┆ f64             ┆ ---                  ┆ str           ┆ f64        │
# │            ┆               ┆                 ┆ str                  ┆               ┆            │
# ╞════════════╪═══════════════╪═════════════════╪══════════════════════╪═══════════════╪════════════╡
# │ count      ┆ 1.107933e6    ┆ 1.107933e6      ┆ 1107933              ┆ 1107933       ┆ 1.107933e6 │
# │ null_count ┆ 0.0           ┆ 0.0             ┆ 0                    ┆ 0             ┆ 0.0        │
# │ mean       ┆ 1.4699e6      ┆ 20104.965724    ┆ null                 ┆ null          ┆ 4.14472    │
# │ std        ┆ 705344.777052 ┆ 25201.745135    ┆ null                 ┆ null          ┆ 4.108048   │
# │ min        ┆ 49435.0       ┆ 0.0             ┆ 2019-09-27           ┆ 00011206      ┆ 0.0        │
# │ 25%        ┆ 997668.0      ┆ 6885.0          ┆ null                 ┆ null          ┆ 1.0        │
# │ 50%        ┆ 1.854645e6    ┆ 13130.2         ┆ null                 ┆ null          ┆ 3.0        │
# │ 75%        ┆ 1.907416e6    ┆ 24300.0         ┆ null                 ┆ null          ┆ 5.0        │
# │ max        ┆ 2.703452e6    ┆ 344250.0        ┆ 2020-10-16           ┆ ffff44de      ┆ 100.0      │
# └────────────┴───────────────┴─────────────────┴──────────────────────┴───────────────┴────────────┘
#
# Missing values count in each column:
# shape: (1, 5)
# ┌─────────┬─────────────────┬────────────────────────┬───────────────┬────────────┐
# │ case_id ┆ amount_4917619A ┆ deductiondate_4917603D ┆ name_4917606M ┆ num_group1 │
# │ ---     ┆ ---             ┆ ---                    ┆ ---           ┆ ---        │
# │ u32     ┆ u32             ┆ u32                    ┆ u32           ┆ u32        │
# ╞═════════╪═════════════════╪════════════════════════╪═══════════════╪════════════╡
# │ 0       ┆ 0               ┆ 0                      ┆ 0             ┆ 0          │
# └─────────┴─────────────────┴────────────────────────┴───────────────┴────────────┘
#
# -----
#
# Overview of train_tax_registry_c:
# OrderedDict([('case_id', Int64), ('employername_160M', String), ('num_group1', Int64), ('pmtamount_36A', Float64), ('processingdate_168D', String)])
# shape: (9, 6)
# ┌────────────┬───────────────┬───────────────────┬────────────┬───────────────┬────────────────────┐
# │ statistic  ┆ case_id       ┆ employername_160M ┆ num_group1 ┆ pmtamount_36A ┆ processingdate_168 │
# │ ---        ┆ ---           ┆ ---               ┆ ---        ┆ ---           ┆ D                  │
# │ str        ┆ f64           ┆ str               ┆ f64        ┆ f64           ┆ ---                │
# │            ┆               ┆                   ┆            ┆               ┆ str                │
# ╞════════════╪═══════════════╪═══════════════════╪════════════╪═══════════════╪════════════════════╡
# │ count      ┆ 3.3438e6      ┆ 3343800           ┆ 3.3438e6   ┆ 3.3438e6      ┆ 3343800            │
# │ null_count ┆ 0.0           ┆ 0                 ┆ 0.0        ┆ 0.0           ┆ 0                  │
# │ mean       ┆ 1.1613e6      ┆ null              ┆ 3.893117   ┆ 2260.537387   ┆ null               │
# │ std        ┆ 657994.955912 ┆ null              ┆ 3.736779   ┆ 3161.294121   ┆ null               │
# │ min        ┆ 357.0         ┆ 000025c1          ┆ 0.0        ┆ 0.0           ┆ 2018-07-11         │
# │ 25%        ┆ 700623.0      ┆ null              ┆ 1.0        ┆ 745.46        ┆ null               │
# │ 50%        ┆ 1.301411e6    ┆ null              ┆ 3.0        ┆ 1365.454      ┆ null               │
# │ 75%        ┆ 1.471673e6    ┆ null              ┆ 5.0        ┆ 2632.2        ┆ null               │
# │ max        ┆ 2.629815e6    ┆ ffffaf43          ┆ 120.0      ┆ 87115.6       ┆ 2019-10-22         │
# └────────────┴───────────────┴───────────────────┴────────────┴───────────────┴────────────────────┘
#
# Missing values count in each column:
# shape: (1, 5)
# ┌─────────┬───────────────────┬────────────┬───────────────┬─────────────────────┐
# │ case_id ┆ employername_160M ┆ num_group1 ┆ pmtamount_36A ┆ processingdate_168D │
# │ ---     ┆ ---               ┆ ---        ┆ ---           ┆ ---                 │
# │ u32     ┆ u32               ┆ u32        ┆ u32           ┆ u32                 │
# ╞═════════╪═══════════════════╪════════════╪═══════════════╪═════════════════════╡
# │ 0       ┆ 0                 ┆ 0          ┆ 0             ┆ 0                   │
# └─────────┴───────────────────┴────────────┴───────────────┴─────────────────────┘
#
# -----

# %%
for name, df in dataframes.items():
    print(f"Null value percentages in {name}:")
    total_rows = len(df)

    # Calculate and print the percentage of null values for each column
    for column in df.columns:
        null_count = df.select(pl.col(column).is_null().sum()).to_numpy()[0, 0]  # Accessing the scalar value directly
        null_percentage = (null_count / total_rows) * 100
        print(f"{column}: {null_percentage:.2f}%")

    print("\n-----\n")
# Out:
# Null value percentages in train_static_0_0:
# case_id: 0.00%
# actualdpdtolerance_344P: 29.56%
# amtinstpaidbefduel24m_4187115A: 42.72%
# annuity_780A: 0.00%
# annuitynextmonth_57A: 0.00%
# applicationcnt_361L: 0.00%
# applications30d_658L: 0.00%
# applicationscnt_1086L: 0.00%
# applicationscnt_464L: 0.00%
# applicationscnt_629L: 0.00%
# applicationscnt_867L: 0.00%
# avgdbddpdlast24m_3658932P: 42.45%
# avgdbddpdlast3m_4187120P: 65.55%
# avgdbdtollast24m_4525197P: 78.28%
# avgdpdtolclosure24_3658938P: 32.80%
# avginstallast24m_3658937A: 43.21%
# avglnamtstart24m_4525187A: 93.05%
# avgmaxdpdlast9m_3716943P: 51.34%
# avgoutstandbalancel6m_4187114A: 59.68%
# avgpmtlast12m_4525200A: 80.43%
# bankacctype_710L: 69.65%
# cardtype_51L: 87.47%
# clientscnt12m_3712952L: 0.00%
# clientscnt3m_3712950L: 0.00%
# clientscnt6m_3712949L: 0.00%
# clientscnt_100L: 0.00%
# clientscnt_1022L: 0.00%
# clientscnt_1071L: 0.00%
# clientscnt_1130L: 0.00%
# clientscnt_136L: 99.96%
# clientscnt_157L: 0.00%
# clientscnt_257L: 0.00%
# clientscnt_304L: 0.00%
# clientscnt_360L: 0.00%
# clientscnt_493L: 0.00%
# clientscnt_533L: 0.00%
# clientscnt_887L: 0.00%
# clientscnt_946L: 0.00%
# cntincpaycont9m_3716944L: 32.09%
# cntpmts24_3658933L: 32.65%
# commnoinclast6m_3546845L: 25.86%
# credamount_770A: 0.00%
# credtype_322L: 0.00%
# currdebt_22A: 0.00%
# currdebtcredtyperange_828A: 0.00%
# datefirstoffer_1144D: 55.86%
# datelastinstal40dpd_247D: 92.88%
# datelastunpaid_3546854D: 60.45%
# daysoverduetolerancedd_3976961L: 31.91%
# deferredmnthsnum_166L: 0.00%
# disbursedcredamount_1113A: 0.00%
# disbursementtype_67L: 0.06%
# downpmt_116A: 0.00%
# dtlastpmtallstes_4499206D: 75.61%
# eir_270L: 12.50%
# equalitydataagreement_891L: 94.79%
# equalityempfrom_62L: 97.17%
# firstclxcampaign_1125D: 56.95%
# firstdatedue_489D: 33.84%
# homephncnt_628L: 0.00%
# inittransactionamount_650A: 87.46%
# inittransactioncode_186L: 0.00%
# interestrate_311L: 12.50%
# interestrategrace_34L: 98.35%
# isbidproduct_1095L: 0.00%
# isbidproductrequest_292L: 99.16%
# isdebitcard_729L: 87.46%
# lastactivateddate_801D: 31.96%
# lastapplicationdate_877D: 21.99%
# lastapprcommoditycat_1041M: 0.00%
# lastapprcommoditytypec_5251766M: 0.00%
# lastapprcredamount_781A: 31.20%
# lastapprdate_640D: 31.20%
# lastcancelreason_561M: 0.00%
# lastdelinqdate_224D: 66.62%
# lastdependentsnum_448L: 97.50%
# lastotherinc_902A: 99.78%
# lastotherlnsexpense_631A: 99.78%
# lastrejectcommoditycat_161M: 0.00%
# lastrejectcommodtypec_5251769M: 0.00%
# lastrejectcredamount_222A: 52.89%
# lastrejectdate_50D: 52.89%
# lastrejectreason_759M: 0.00%
# lastrejectreasonclient_4145040M: 0.00%
# lastrepayingdate_696D: 99.84%
# lastst_736L: 21.99%
# maininc_215A: 33.97%
# mastercontrelectronic_519L: 22.13%
# mastercontrexist_109L: 22.13%
# maxannuity_159A: 22.13%
# maxannuity_4075009A: 95.01%
# maxdbddpdlast1m_3658939P: 64.05%
# maxdbddpdtollast12m_3658940P: 48.14%
# maxdbddpdtollast6m_4187119P: 61.45%
# maxdebt4_972A: 22.13%
# maxdpdfrom6mto36m_3546853P: 25.86%
# maxdpdinstldate_3546855D: 56.57%
# maxdpdinstlnum_3546846P: 56.69%
# maxdpdlast12m_727P: 22.13%
# maxdpdlast24m_143P: 22.13%
# maxdpdlast3m_392P: 22.13%
# maxdpdlast6m_474P: 22.13%
# maxdpdlast9m_1059P: 22.13%
# maxdpdtolerance_374P: 22.13%
# maxinstallast24m_3658928A: 43.21%
# maxlnamtstart6m_4525199A: 80.44%
# maxoutstandbalancel12m_4187113A: 55.31%
# maxpmtlast3m_4525190A: 84.28%
# mindbddpdlast24m_3658935P: 42.45%
# mindbdtollast24m_4525191P: 78.28%
# mobilephncnt_593L: 0.00%
# monthsannuity_845L: 31.91%
# numactivecreds_622L: 0.00%
# numactivecredschannel_414L: 0.00%
# numactiverelcontr_750L: 0.00%
# numcontrs3months_479L: 0.00%
# numincomingpmts_3546848L: 32.08%
# numinstlallpaidearly3d_817L: 31.42%
# numinstls_657L: 0.00%
# numinstlsallpaid_934L: 31.42%
# numinstlswithdpd10_728L: 32.18%
# numinstlswithdpd5_4187116L: 42.72%
# numinstlswithoutdpd_562L: 32.18%
# numinstmatpaidtearly2d_4499204L: 71.22%
# numinstpaid_4499208L: 71.22%
# numinstpaidearly3d_3546850L: 31.55%
# numinstpaidearly3dest_4493216L: 70.57%
# numinstpaidearly5d_1087L: 31.91%
# numinstpaidearly5dest_4493211L: 70.57%
# numinstpaidearly5dobd_4499205L: 71.22%
# numinstpaidearly_338L: 31.91%
# numinstpaidearlyest_4493214L: 70.57%
# numinstpaidlastcontr_4325080L: 53.49%
# numinstpaidlate1d_3546852L: 31.91%
# numinstregularpaid_973L: 32.21%
# numinstregularpaidest_4493210L: 70.57%
# numinsttopaygr_769L: 31.91%
# numinsttopaygrest_4493213L: 70.57%
# numinstunpaidmax_3546851L: 31.91%
# numinstunpaidmaxest_4493212L: 70.57%
# numnotactivated_1143L: 0.00%
# numpmtchanneldd_318L: 0.00%
# numrejects9m_859L: 0.00%
# opencred_647L: 21.99%
# paytype1st_925L: 0.11%
# paytype_783L: 0.11%
# payvacationpostpone_4187118D: 99.85%
# pctinstlsallpaidearl3d_427L: 32.28%
# pctinstlsallpaidlat10d_839L: 32.47%
# pctinstlsallpaidlate1d_3546856L: 32.28%
# pctinstlsallpaidlate4d_3546849L: 32.36%
# pctinstlsallpaidlate6d_3546844L: 32.37%
# pmtnum_254L: 2.85%
# posfpd10lastmonth_333P: 1.91%
# posfpd30lastmonth_3976960P: 6.36%
# posfstqpd30lastmonth_3976962P: 9.21%
# previouscontdistrict_112M: 0.00%
# price_1097A: 13.39%
# sellerplacecnt_915L: 0.00%
# sellerplacescnt_216L: 0.00%
# sumoutstandtotal_3546847A: 31.46%
# sumoutstandtotalest_4493215A: 70.57%
# totaldebt_9A: 0.00%
# totalsettled_863A: 0.00%
# totinstallast1m_4525188A: 86.18%
# twobodfilling_608L: 0.00%
# typesuite_864L: 71.26%
# validfrom_1069D: 88.10%
#
# -----
#
# Null value percentages in train_static_0_1:
# case_id: 0.00%
# actualdpdtolerance_344P: 23.23%
# amtinstpaidbefduel24m_4187115A: 25.30%
# annuity_780A: 0.00%
# annuitynextmonth_57A: 0.00%
# applicationcnt_361L: 0.00%
# applications30d_658L: 0.00%
# applicationscnt_1086L: 0.00%
# applicationscnt_464L: 0.00%
# applicationscnt_629L: 0.00%
# applicationscnt_867L: 0.00%
# avgdbddpdlast24m_3658932P: 35.78%
# avgdbddpdlast3m_4187120P: 55.51%
# avgdbdtollast24m_4525197P: 35.78%
# avgdpdtolclosure24_3658938P: 26.37%
# avginstallast24m_3658937A: 36.56%
# avglnamtstart24m_4525187A: 82.27%
# avgmaxdpdlast9m_3716943P: 46.23%
# avgoutstandbalancel6m_4187114A: 46.32%
# avgpmtlast12m_4525200A: 42.01%
# bankacctype_710L: 78.52%
# cardtype_51L: 87.40%
# clientscnt12m_3712952L: 0.00%
# clientscnt3m_3712950L: 0.00%
# clientscnt6m_3712949L: 0.00%
# clientscnt_100L: 0.00%
# clientscnt_1022L: 0.00%
# clientscnt_1071L: 0.00%
# clientscnt_1130L: 0.00%
# clientscnt_136L: 100.00%
# clientscnt_157L: 0.00%
# clientscnt_257L: 0.00%
# clientscnt_304L: 0.00%
# clientscnt_360L: 0.00%
# clientscnt_493L: 0.00%
# clientscnt_533L: 0.00%
# clientscnt_887L: 0.00%
# clientscnt_946L: 0.00%
# cntincpaycont9m_3716944L: 25.46%
# cntpmts24_3658933L: 25.45%
# commnoinclast6m_3546845L: 16.04%
# credamount_770A: 0.00%
# credtype_322L: 0.00%
# currdebt_22A: 0.00%
# currdebtcredtyperange_828A: 0.00%
# datefirstoffer_1144D: 52.21%
# datelastinstal40dpd_247D: 88.08%
# datelastunpaid_3546854D: 53.72%
# daysoverduetolerancedd_3976961L: 25.30%
# deferredmnthsnum_166L: 0.00%
# disbursedcredamount_1113A: 0.00%
# disbursementtype_67L: 0.05%
# downpmt_116A: 0.00%
# dtlastpmtallstes_4499206D: 41.73%
# eir_270L: 12.49%
# equalitydataagreement_891L: 95.08%
# equalityempfrom_62L: 98.20%
# firstclxcampaign_1125D: 54.99%
# firstdatedue_489D: 27.24%
# homephncnt_628L: 0.00%
# inittransactionamount_650A: 87.30%
# inittransactioncode_186L: 0.00%
# interestrate_311L: 12.49%
# interestrategrace_34L: 99.18%
# isbidproduct_1095L: 0.00%
# isbidproductrequest_292L: 99.24%
# isdebitcard_729L: 87.30%
# lastactivateddate_801D: 25.39%
# lastapplicationdate_877D: 16.14%
# lastapprcommoditycat_1041M: 0.00%
# lastapprcommoditytypec_5251766M: 0.00%
# lastapprcredamount_781A: 24.65%
# lastapprdate_640D: 24.65%
# lastcancelreason_561M: 0.00%
# lastdelinqdate_224D: 59.15%
# lastdependentsnum_448L: 99.15%
# lastotherinc_902A: 99.84%
# lastotherlnsexpense_631A: 99.83%
# lastrejectcommoditycat_161M: 0.00%
# lastrejectcommodtypec_5251769M: 0.00%
# lastrejectcredamount_222A: 45.54%
# lastrejectdate_50D: 45.54%
# lastrejectreason_759M: 0.00%
# lastrejectreasonclient_4145040M: 0.00%
# lastrepayingdate_696D: 99.85%
# lastst_736L: 16.14%
# maininc_215A: 32.57%
# mastercontrelectronic_519L: 16.04%
# mastercontrexist_109L: 16.04%
# maxannuity_159A: 16.04%
# maxannuity_4075009A: 95.06%
# maxdbddpdlast1m_3658939P: 60.82%
# maxdbddpdtollast12m_3658940P: 42.52%
# maxdbddpdtollast6m_4187119P: 49.62%
# maxdebt4_972A: 16.04%
# maxdpdfrom6mto36m_3546853P: 16.04%
# maxdpdinstldate_3546855D: 49.38%
# maxdpdinstlnum_3546846P: 49.80%
# maxdpdlast12m_727P: 16.04%
# maxdpdlast24m_143P: 16.04%
# maxdpdlast3m_392P: 16.04%
# maxdpdlast6m_474P: 16.04%
# maxdpdlast9m_1059P: 16.04%
# maxdpdtolerance_374P: 16.04%
# maxinstallast24m_3658928A: 36.56%
# maxlnamtstart6m_4525199A: 43.10%
# maxoutstandbalancel12m_4187113A: 40.50%
# maxpmtlast3m_4525190A: 54.19%
# mindbddpdlast24m_3658935P: 35.78%
# mindbdtollast24m_4525191P: 35.78%
# mobilephncnt_593L: 0.00%
# monthsannuity_845L: 25.30%
# numactivecreds_622L: 0.00%
# numactivecredschannel_414L: 0.00%
# numactiverelcontr_750L: 0.00%
# numcontrs3months_479L: 0.00%
# numincomingpmts_3546848L: 25.45%
# numinstlallpaidearly3d_817L: 24.91%
# numinstls_657L: 0.00%
# numinstlsallpaid_934L: 24.91%
# numinstlswithdpd10_728L: 25.53%
# numinstlswithdpd5_4187116L: 25.30%
# numinstlswithoutdpd_562L: 25.53%
# numinstmatpaidtearly2d_4499204L: 25.30%
# numinstpaid_4499208L: 25.30%
# numinstpaidearly3d_3546850L: 24.91%
# numinstpaidearly3dest_4493216L: 25.30%
# numinstpaidearly5d_1087L: 25.30%
# numinstpaidearly5dest_4493211L: 25.30%
# numinstpaidearly5dobd_4499205L: 25.30%
# numinstpaidearly_338L: 25.30%
# numinstpaidearlyest_4493214L: 25.30%
# numinstpaidlastcontr_4325080L: 25.30%
# numinstpaidlate1d_3546852L: 25.30%
# numinstregularpaid_973L: 25.30%
# numinstregularpaidest_4493210L: 25.30%
# numinsttopaygr_769L: 25.30%
# numinsttopaygrest_4493213L: 25.30%
# numinstunpaidmax_3546851L: 25.30%
# numinstunpaidmaxest_4493212L: 25.30%
# numnotactivated_1143L: 0.00%
# numpmtchanneldd_318L: 0.00%
# numrejects9m_859L: 0.00%
# opencred_647L: 16.14%
# paytype1st_925L: 11.00%
# paytype_783L: 11.00%
# payvacationpostpone_4187118D: 98.50%
# pctinstlsallpaidearl3d_427L: 25.76%
# pctinstlsallpaidlat10d_839L: 25.91%
# pctinstlsallpaidlate1d_3546856L: 25.76%
# pctinstlsallpaidlate4d_3546849L: 25.83%
# pctinstlsallpaidlate6d_3546844L: 25.84%
# pmtnum_254L: 3.12%
# posfpd10lastmonth_333P: 11.35%
# posfpd30lastmonth_3976960P: 13.02%
# posfstqpd30lastmonth_3976962P: 16.96%
# previouscontdistrict_112M: 0.00%
# price_1097A: 17.00%
# sellerplacecnt_915L: 0.00%
# sellerplacescnt_216L: 0.00%
# sumoutstandtotal_3546847A: 24.77%
# sumoutstandtotalest_4493215A: 25.30%
# totaldebt_9A: 0.00%
# totalsettled_863A: 0.00%
# totinstallast1m_4525188A: 59.12%
# twobodfilling_608L: 0.01%
# typesuite_864L: 77.69%
# validfrom_1069D: 93.81%
#
# -----
#
# Null value percentages in train_static_cb:
# case_id: 0.00%
# assignmentdate_238D: 90.87%
# assignmentdate_4527235D: 92.34%
# assignmentdate_4955616D: 95.23%
# birthdate_574D: 59.49%
# contractssum_5085716L: 89.51%
# dateofbirth_337D: 7.65%
# dateofbirth_342D: 97.57%
# days120_123L: 7.65%
# days180_256L: 7.65%
# days30_165L: 7.65%
# days360_512L: 7.65%
# days90_310L: 7.65%
# description_5085714M: 0.00%
# education_1103M: 0.00%
# education_88M: 0.00%
# firstquarter_103L: 7.65%
# for3years_128L: 97.57%
# for3years_504L: 97.57%
# for3years_584L: 97.57%
# formonth_118L: 97.57%
# formonth_206L: 97.57%
# formonth_535L: 97.57%
# forquarter_1017L: 97.57%
# forquarter_462L: 97.57%
# forquarter_634L: 97.57%
# fortoday_1092L: 97.57%
# forweek_1077L: 97.57%
# forweek_528L: 97.57%
# forweek_601L: 97.57%
# foryear_618L: 97.57%
# foryear_818L: 97.57%
# foryear_850L: 97.57%
# fourthquarter_440L: 7.65%
# maritalst_385M: 0.00%
# maritalst_893M: 0.00%
# numberofqueries_373L: 7.65%
# pmtaverage_3A: 90.43%
# pmtaverage_4527227A: 92.34%
# pmtaverage_4955615A: 95.21%
# pmtcount_4527229L: 92.34%
# pmtcount_4955617L: 95.21%
# pmtcount_693L: 90.24%
# pmtscount_423L: 61.84%
# pmtssum_45A: 61.84%
# requesttype_4525192L: 55.13%
# responsedate_1012D: 52.02%
# responsedate_4527233D: 55.99%
# responsedate_4917613D: 85.01%
# riskassesment_302T: 96.43%
# riskassesment_940T: 96.43%
# secondquarter_766L: 7.65%
# thirdquarter_1082L: 7.65%
#
# -----
#
# Null value percentages in train_tax_registry_a:
# case_id: 0.00%
# amount_4527230A: 0.00%
# name_4527232M: 0.00%
# num_group1: 0.00%
# recorddate_4527225D: 0.00%
#
# -----
#
# Null value percentages in train_tax_registry_b:
# case_id: 0.00%
# amount_4917619A: 0.00%
# deductiondate_4917603D: 0.00%
# name_4917606M: 0.00%
# num_group1: 0.00%
#
# -----
#
# Null value percentages in train_tax_registry_c:
# case_id: 0.00%
# employername_160M: 0.00%
# num_group1: 0.00%
# pmtamount_36A: 0.00%
# processingdate_168D: 0.00%
#
# -----

# %% [markdown]
# After we checked the data overall, lets do the data aggregation

# %%
# Aggregation functions for numerical columns
numerical_agg_funcs = {
    'min': 'min',
    'max': 'max',
    'mean': 'mean',
    'median': 'median',
    'sum': 'sum'
}

# Aggregation functions for categorical columns
categorical_agg_funcs = {
    'mode': lambda x: x.mode().iloc[0],  # Mode
    'one_hot_encoding': lambda x: x.sum()  # One-hot encoding with sum of counts
}

# Aggregation functions for date columns
date_agg_funcs = {
    'min': 'min',
    'max': 'max',
    'distinct_count': 'nunique'  # Count of distinct values
}

# %% [markdown]
# Train Static 0 Aggregation

# %%
# Date columns
date_cols = [ train_static_0_0.columns[i] for i in range(len(train_static_0_0.columns)) if (train_static_0_0.columns[i].__contains__('dat')) and (train_static_0_0.dtypes[i] == pl.String) ]

# Categorical columns
cat_cols = [ train_static_0_0.columns[i] for i in range(len(train_static_0_0.columns)) if (train_static_0_0.columns[i] not in date_cols) and (train_static_0_0.dtypes[i] == pl.String) ]

# Numerical columns
ignore_col = ['case_id']
num_col = [ 
    train_static_0_0.columns[i] for i in range(len(train_static_0_0.columns)) 
    if (train_static_0_0.columns[i] not in date_cols) and (train_static_0_0.columns[i] not in cat_cols) and (train_static_0_0.columns[i] not in ignore_col)
]

# Group data
train_static_0_agg = group_file_data(train_static_0_0, num_col, date_cols, cat_cols)

# %%
train_static_0_agg.head()
# Out:
# shape: (5, 7_057)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ case_id ┆ actualdpdt ┆ amtinstpa ┆ annuity_7 ┆ … ┆ validfrom ┆ validfrom ┆ validfrom ┆ validfrom │
# │ ---     ┆ olerance_3 ┆ idbefduel ┆ 80A_min   ┆   ┆ _1069D_20 ┆ _1069D_20 ┆ _1069D_20 ┆ _1069D_nu │
# │ i64     ┆ 44P_min    ┆ 24m_41871 ┆ ---       ┆   ┆ 19-12-28_ ┆ 19-12-29_ ┆ 19-12-30_ ┆ ll_sum    │
# │         ┆ ---        ┆ 15A_m…    ┆ f64       ┆   ┆ sum       ┆ sum       ┆ sum       ┆ ---       │
# │         ┆ f64        ┆ ---       ┆           ┆   ┆ ---       ┆ ---       ┆ ---       ┆ i64       │
# │         ┆            ┆ f64       ┆           ┆   ┆ i64       ┆ i64       ┆ i64       ┆           │
# ╞═════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 1305573 ┆ 0.0        ┆ null      ┆ 2741.4001 ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 1         │
# │ 789395  ┆ null       ┆ null      ┆ 3665.0    ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 1         │
# │ 851903  ┆ null       ┆ null      ┆ 6023.4    ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 1         │
# │ 1555141 ┆ 0.0        ┆ 0.0       ┆ 3038.8    ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 1         │
# │ 114861  ┆ 0.0        ┆ null      ┆ 1585.2001 ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 1         │
# └─────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
train_static_0_agg.write_parquet(dataPath + 'train_static_0_grouped.parquet')

# %% [markdown]
# Train Static 1 Aggregation

# %%
# Date columns
date_cols = [ train_static_0_1.columns[i] for i in range(len(train_static_0_1.columns)) if (train_static_0_1.columns[i].__contains__('dat')) and (train_static_0_1.dtypes[i] == pl.String) ]

# Categorical columns
cat_cols = [ train_static_0_1.columns[i] for i in range(len(train_static_0_1.columns)) if (train_static_0_1.columns[i] not in date_cols) and (train_static_0_1.dtypes[i] == pl.String) ]

# Numerical columns
ignore_col = ['case_id']
num_col = [ 
    train_static_0_1.columns[i] for i in range(len(train_static_0_1.columns)) 
    if (train_static_0_1.columns[i] not in date_cols) and (train_static_0_1.columns[i] not in cat_cols) and (train_static_0_1.columns[i] not in ignore_col)
]

# Group data
train_static_1_agg = group_file_data(train_static_0_1, num_col, date_cols, cat_cols)

# %%
train_static_1_agg.head()

# %%
train_static_0_agg.write_parquet(dataPath + 'train_static_1_grouped.parquet')

# %% [markdown]
# Train Static cb Aggregation

# %%
# Date columns
date_cols = [ train_static_cb.columns[i] for i in range(len(train_static_cb.columns)) if (train_static_cb.columns[i].__contains__('dat')) and (train_static_cb.dtypes[i] == pl.String) ]

# Categorical columns
cat_cols = [ train_static_cb.columns[i] for i in range(len(train_static_cb.columns)) if (train_static_cb.columns[i] not in date_cols) and (train_static_cb.dtypes[i] == pl.String) ]

# Numerical columns
ignore_col = ['case_id']
num_col = [ 
    train_static_cb.columns[i] for i in range(len(train_static_cb.columns)) 
    if (train_static_cb.columns[i] not in date_cols) and (train_static_cb.columns[i] not in cat_cols) and (train_static_cb.columns[i] not in ignore_col)
]

# Group data
train_static_cb_agg = group_file_data(train_static_cb, num_col, date_cols, cat_cols)

# %%
train_static_cb_agg.head()

# %%
train_static_cb_agg.write_parquet(dataPath + 'train_static_cb_grouped.parquet')

# %% [markdown]
# Train Tax Registry A Aggregation

# %%
# Date columns
date_cols = [ train_tax_registry_a.columns[i] for i in range(len(train_tax_registry_a.columns)) if (train_tax_registry_a.columns[i].__contains__('dat')) and (train_tax_registry_a.dtypes[i] == pl.String) ]

# Categorical columns
cat_cols = [ train_tax_registry_a.columns[i] for i in range(len(train_tax_registry_a.columns)) if (train_tax_registry_a.columns[i] not in date_cols) and (train_tax_registry_a.dtypes[i] == pl.String) ]

# Numerical columns
ignore_col = ['case_id', "num_group1"]
num_col = [ 
    train_tax_registry_a.columns[i] for i in range(len(train_tax_registry_a.columns)) 
    if (train_tax_registry_a.columns[i] not in date_cols) and (train_tax_registry_a.columns[i] not in cat_cols) and (train_tax_registry_a.columns[i] not in ignore_col)
]

# Group data
train_tax_reg_a_agg = group_file_data(train_tax_registry_a, num_col, date_cols, cat_cols)

# %%
train_tax_reg_a_agg.head()

# %%
train_tax_reg_a_agg.write_parquet(dataPath + 'train_tax_registry_a_grouped.parquet')

# %% [markdown]
# Train Tax Registry B Aggregation

# %%
# Date columns
date_cols = [ train_tax_registry_b.columns[i] for i in range(len(train_tax_registry_b.columns)) if (train_tax_registry_b.columns[i].__contains__('dat')) and (train_tax_registry_b.dtypes[i] == pl.String) ]

# Categorical columns
cat_cols = [ train_tax_registry_b.columns[i] for i in range(len(train_tax_registry_b.columns)) if (train_tax_registry_b.columns[i] not in date_cols) and (train_tax_registry_b.dtypes[i] == pl.String) ]

# Numerical columns
ignore_col = ['case_id', "num_group1"]
num_col = [ 
    train_tax_registry_b.columns[i] for i in range(len(train_tax_registry_b.columns)) 
    if (train_tax_registry_b.columns[i] not in date_cols) and (train_tax_registry_b.columns[i] not in cat_cols) and (train_tax_registry_b.columns[i] not in ignore_col)
]

# Group data
train_tax_reg_b_agg = group_file_data(train_tax_registry_b, num_col, date_cols, cat_cols)

# %%
train_tax_reg_b_agg.head()

# %%
train_tax_reg_b_agg.write_parquet(dataPath + 'train_tax_registry_b_grouped.parquet')

# %% [markdown]
# Train Tax Registry C Aggregation

# %%
# Date columns
date_cols = [ train_tax_registry_c.columns[i] for i in range(len(train_tax_registry_c.columns)) if (train_tax_registry_c.columns[i].__contains__('dat')) and (train_tax_registry_c.dtypes[i] == pl.String) ]

# Categorical columns
cat_cols = [ train_tax_registry_c.columns[i] for i in range(len(train_tax_registry_c.columns)) if (train_tax_registry_c.columns[i] not in date_cols) and (train_tax_registry_c.dtypes[i] == pl.String) ]

# Numerical columns
ignore_col = ['case_id', "num_group1"]
num_col = [ 
    train_tax_registry_c.columns[i] for i in range(len(train_tax_registry_c.columns)) 
    if (train_tax_registry_c.columns[i] not in date_cols) and (train_tax_registry_c.columns[i] not in cat_cols) and (train_tax_registry_c.columns[i] not in ignore_col)
]

# Group data
train_tax_reg_c_agg = group_file_data(train_tax_registry_c, num_col, date_cols, cat_cols)

# %%
train_tax_reg_c_agg.head()

# %%
train_tax_reg_c_agg.write_parquet(dataPath + 'train_tax_registry_c_grouped.parquet')

# %% [markdown]
# Joining all aggregated tables together into the basetable

# %%
# Join all tables together.
data = train_basetable.join(
    train_static_0_agg, how="left", on="case_id"
).join(
    train_static_1_agg, how="left", on="case_id"
).join(
    train_static_cb, how="left", on="case_id"
).join(
    train_tax_reg_a_agg, how="left", on="case_id"
).join(
    train_tax_reg_b_agg, how="left", on="case_id"
).join(
    train_tax_reg_c_agg, how="left", on="case_id"
)
